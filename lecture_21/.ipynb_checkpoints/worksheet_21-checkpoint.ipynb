# %% [markdown]
# # Worksheet 21
#
# Name: Aryan Agarwal
# UID: U36516144
#
# ### Topics
#
# - Logistic Regression
#
# ## Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=750, centers=centers, cluster_std=1, random_state=0)

# LINE
def generate_line_data():
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

# %% [markdown]
# a) Using the above code, generate and plot data that is linearly separable.

# %%
def generate_and_plot_linear_data():
    X, Y = generate_line_data()
    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired, edgecolors='k')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

generate_and_plot_linear_data()

# %% [markdown]
# b) Fit a logistic regression model to the data a print out the coefficients.

# %%
X, Y = generate_line_data()

model = LogisticRegression().fit(X, Y)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [[ 4.11337993 -4.10105513]]
# Intercept: [0.05839469]

# %% [markdown]
# c) Using the coefficients, plot the line through the scatter plot you created in a). (Note: you need to do some math to get the line in the right form)

# %%
X, Y = generate_line_data()

model = LogisticRegression().fit(X, Y)

coef = model.coef_[0]
intercept = model.intercept_[0]

plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired, edgecolors='k')

x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contour(xx, yy, Z, colors='k', linewidths=1)

x_plot = np.linspace(x_min, x_max, 100)
y_plot = -(coef[0] / coef[1]) * x_plot - (intercept / coef[1])
plt.plot(x_plot, y_plot, '-r', label='Decision Boundary')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

plt.legend()
plt.show()

# %% [markdown]
# d) Using the above code, generate and plot the CIRCLE data.

# %%
def generate_and_plot_circle_data():
    X, Y = generate_circle_data(t)

    model = LogisticRegression().fit(X, Y)

    coef = model.coef_[0]
    intercept = model.intercept_[0]

    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired, edgecolors='k')

    theta = np.linspace(0, 2*np.pi, 100)
    x_plot = centers[0][0] + np.cos(theta)
    y_plot = centers[0][1] + np.sin(theta)

    plt.plot(x_plot, y_plot, '-r', label='Decision Boundary')

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')

    plt.legend()
    plt.axis('equal')
    plt.show()

generate_and_plot_circle_data()

# %% [markdown]
# e) Notice that the equation of an ellipse is of the form $$ax^2 + by^2 = c$$
#
# Fit a logistic regression model to an appropriate transformation of X.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

def generate_and_plot_ellipse_data():
    X, Y = generate_circle_data(t)

    poly = PolynomialFeatures(degree=2)
    X_transformed = poly.fit_transform(X)

    model = make_pipeline(PolynomialFeatures(degree=2), LogisticRegression()).fit(X, Y)

    coef = model.named_steps['logisticregression'].coef_[0]
    intercept = model.named_steps['logisticregression'].intercept_[0]

    plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Paired, edgecolors='k')

    theta = np.linspace(0, 2*np.pi, 100)
    x_plot = centers[0][0] + np.cos(theta)
    y_plot = centers[0][1] + np.sin(theta)

    plt.plot(x_plot, y_plot, '-r', label='Decision Boundary Ellipse')

    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')

    plt.legend()
    plt.axis('equal')
    plt.show()

generate_and_plot_ellipse_data()

# %% [markdown]
# f) Plot the decision boundary using the code below.

# %%
# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
A = model.predict_proba(meshData)[:, 1].reshape(xx.shape)
Z = model.predict(meshData).reshape(xx.shape)
ax.contourf(xx, yy, A, cmap="RdBu", vmin=0, vmax=1)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], c=Y, s=50, alpha=0.9)
plt.show()

# %% [markdown]
# g) Plot the XOR data. In this 2D space, the data is not linearly separable, but by introducing a new feature $$x_3 = x_1 * x_2$$
#
# (called an interaction term) we should be able to find a hyperplane that separates the data in 3D. Plot this new dataset in 3D.

# %%
from mpl_toolkits.mplot3d import Axes3D

X, Y = generate_xor_data()
ax = plt.axes(projection='3d')
ax.scatter3D(X[: , 0], X[: , 1], X[: , 0]* X[: , 1], c=Y)
plt.show()

# %% [markdown]
# h) Apply a logistic regression model using the interaction term. Plot the decision boundary.

# %%
poly = PolynomialFeatures(interaction_only=True)
lr = LogisticRegression(verbose=0)
model = make_pipeline(poly, lr).fit(X, Y)

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
A = model.predict_proba(meshData)[:, 1].reshape(xx.shape)
Z = model.predict(meshData).reshape(xx.shape)
ax.contourf(xx, yy, A, cmap="RdBu", vmin=0, vmax=1)
ax.axis('off')

# Plot also the training points
ax.scatter(X[:, 0], X[:, 1], color=Y, s=50, alpha=0.9)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures

X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]])
Y = np.array([x[0] ^ x[1] for x in X])

# %matplotlib widget

fig = plt.figure(figsize=(8, 8))

for i in range(500):
    for solver in ['lbfgs', 'liblinear', 'newton-cg', 'sag', 'saga']: 
        X_transform = PolynomialFeatures(interaction_only=True, include_bias=False).fit_transform(X)
        model = LogisticRegression(verbose=0, solver=solver, random_state=i, max_iter=10000)
        model.fit(X_transform, Y)
        score = model.score(X_transform, Y)
        print(f"Random state: {i}, Solver: {solver}, Score: {score}")
        if score > 0.75:
            print("Random state =", i)
            print("Solver =", solver)
            break

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

xx, yy = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-1, 1, 100))
z = - model.intercept_ / model.coef_[0][2] - model.coef_[0][0] * xx / model.coef_[0][2] - model.coef_[0][1] * yy / model.coef_[0][2]

ax1 = fig.add_subplot(121, projection='3d')
ax1.scatter3D(X[:, 0], X[:, 1], X[:, 0] * X[:, 1], c=Y)

ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(xx, yy, z, alpha=0.5)

plt.show()
# Out:
# Random state: 0, Solver: lbfgs, Score: 0.75
# Random state: 0, Solver: liblinear, Score: 0.75
# Random state: 0, Solver: newton-cg, Score: 0.75
# Random state: 0, Solver: sag, Score: 0.75
# Random state: 0, Solver: saga, Score: 0.75
# Random state: 1, Solver: lbfgs, Score: 0.75
# Random state: 1, Solver: liblinear, Score: 0.75
# Random state: 1, Solver: newton-cg, Score: 0.75
# Random state: 1, Solver: sag, Score: 0.75
# Random state: 1, Solver: saga, Score: 0.75
# Random state: 2, Solver: lbfgs, Score: 0.75
# Random state: 2, Solver: liblinear, Score: 0.75
# Random state: 2, Solver: newton-cg, Score: 0.75
# Random state: 2, Solver: sag, Score: 0.75
# Random state: 2, Solver: saga, Score: 0.75
# Random state: 3, Solver: lbfgs, Score: 0.75
# Random state: 3, Solver: liblinear, Score: 0.75
# Random state: 3, Solver: newton-cg, Score: 0.75
# Random state: 3, Solver: sag, Score: 0.75
# Random state: 3, Solver: saga, Score: 0.75
# Random state: 4, Solver: lbfgs, Score: 0.75
# Random state: 4, Solver: liblinear, Score: 0.75
# Random state: 4, Solver: newton-cg, Score: 0.75
# Random state: 4, Solver: sag, Score: 0.75
# Random state: 4, Solver: saga, Score: 0.75
# Random state: 5, Solver: lbfgs, Score: 0.75
# Random state: 5, Solver: liblinear, Score: 0.75
# Random state: 5, Solver: newton-cg, Score: 0.75
# Random state: 5, Solver: sag, Score: 0.75
# Random state: 5, Solver: saga, Score: 0.75
# Random state: 6, Solver: lbfgs, Score: 0.75
# Random state: 6, Solver: liblinear, Score: 0.75
# Random state: 6, Solver: newton-cg, Score: 0.75
# Random state: 6, Solver: sag, Score: 0.75
# Random state: 6, Solver: saga, Score: 0.75
# Random state: 7, Solver: lbfgs, Score: 0.75
# Random state: 7, Solver: liblinear, Score: 0.75
# Random state: 7, Solver: newton-cg, Score: 0.75
# Random state: 7, Solver: sag, Score: 0.75
# Random state: 7, Solver: saga, Score: 0.75
# Random state: 8, Solver: lbfgs, Score: 0.75
# Random state: 8, Solver: liblinear, Score: 0.75
# Random state: 8, Solver: newton-cg, Score: 0.75
# Random state: 8, Solver: sag, Score: 0.75
# Random state: 8, Solver: saga, Score: 0.75
# Random state: 9, Solver: lbfgs, Score: 0.75
# Random state: 9, Solver: liblinear, Score: 0.75
# Random state: 9, Solver: newton-cg, Score: 0.75
# Random state: 9, Solver: sag, Score: 0.75
# Random state: 9, Solver: saga, Score: 0.75
# Random state: 10, Solver: lbfgs, Score: 0.75
# Random state: 10, Solver: liblinear, Score: 0.75
# Random state: 10, Solver: newton-cg, Score: 0.75
# Random state: 10, Solver: sag, Score: 0.75
# Random state: 10, Solver: saga, Score: 0.75
# Random state: 11, Solver: lbfgs, Score: 0.75
# Random state: 11, Solver: liblinear, Score: 0.75
# Random state: 11, Solver: newton-cg, Score: 0.75
# Random state: 11, Solver: sag, Score: 0.75
# Random state: 11, Solver: saga, Score: 0.75
# Random state: 12, Solver: lbfgs, Score: 0.75
# Random state: 12, Solver: liblinear, Score: 0.75
# Random state: 12, Solver: newton-cg, Score: 0.75
# Random state: 12, Solver: sag, Score: 0.75
# Random state: 12, Solver: saga, Score: 0.75
# Random state: 13, Solver: lbfgs, Score: 0.75
# Random state: 13, Solver: liblinear, Score: 0.75
# Random state: 13, Solver: newton-cg, Score: 0.75
# Random state: 13, Solver: sag, Score: 0.75
# Random state: 13, Solver: saga, Score: 0.75
# Random state: 14, Solver: lbfgs, Score: 0.75
# Random state: 14, Solver: liblinear, Score: 0.75
# Random state: 14, Solver: newton-cg, Score: 0.75
# Random state: 14, Solver: sag, Score: 0.75
# Random state: 14, Solver: saga, Score: 0.75
# Random state: 15, Solver: lbfgs, Score: 0.75
# Random state: 15, Solver: liblinear, Score: 0.75
# Random state: 15, Solver: newton-cg, Score: 0.75
# Random state: 15, Solver: sag, Score: 0.75
# Random state: 15, Solver: saga, Score: 0.75
# Random state: 16, Solver: lbfgs, Score: 0.75
# Random state: 16, Solver: liblinear, Score: 0.75
# Random state: 16, Solver: newton-cg, Score: 0.75
# Random state: 16, Solver: sag, Score: 0.75
# Random state: 16, Solver: saga, Score: 0.75
# Random state: 17, Solver: lbfgs, Score: 0.75
# Random state: 17, Solver: liblinear, Score: 0.75
# Random state: 17, Solver: newton-cg, Score: 0.75
# Random state: 17, Solver: sag, Score: 0.75
# Random state: 17, Solver: saga, Score: 0.75
# Random state: 18, Solver: lbfgs, Score: 0.75
# Random state: 18, Solver: liblinear, Score: 0.75
# Random state: 18, Solver: newton-cg, Score: 0.75
# Random state: 18, Solver: sag, Score: 0.75
# Random state: 18, Solver: saga, Score: 0.75
# Random state: 19, Solver: lbfgs, Score: 0.75
# Random state: 19, Solver: liblinear, Score: 0.75
# Random state: 19, Solver: newton-cg, Score: 0.75
# Random state: 19, Solver: sag, Score: 0.75
# Random state: 19, Solver: saga, Score: 0.75
# Random state: 20, Solver: lbfgs, Score: 0.75
# Random state: 20, Solver: liblinear, Score: 0.75
# Random state: 20, Solver: newton-cg, Score: 0.75
# Random state: 20, Solver: sag, Score: 0.75
# Random state: 20, Solver: saga, Score: 0.75
# Random state: 21, Solver: lbfgs, Score: 0.75
# Random state: 21, Solver: liblinear, Score: 0.75
# Random state: 21, Solver: newton-cg, Score: 0.75
# Random state: 21, Solver: sag, Score: 0.75
# Random state: 21, Solver: saga, Score: 0.75
# Random state: 22, Solver: lbfgs, Score: 0.75
# Random state: 22, Solver: liblinear, Score: 0.75
# Random state: 22, Solver: newton-cg, Score: 0.75
# Random state: 22, Solver: sag, Score: 0.75
# Random state: 22, Solver: saga, Score: 0.75
# Random state: 23, Solver: lbfgs, Score: 0.75
# Random state: 23, Solver: liblinear, Score: 0.75
# Random state: 23, Solver: newton-cg, Score: 0.75
# Random state: 23, Solver: sag, Score: 0.75
# Random state: 23, Solver: saga, Score: 0.75
# Random state: 24, Solver: lbfgs, Score: 0.75
# Random state: 24, Solver: liblinear, Score: 0.75
# Random state: 24, Solver: newton-cg, Score: 0.75
# Random state: 24, Solver: sag, Score: 0.75
# Random state: 24, Solver: saga, Score: 0.75
# Random state: 25, Solver: lbfgs, Score: 0.75
# Random state: 25, Solver: liblinear, Score: 0.75
# Random state: 25, Solver: newton-cg, Score: 0.75
# Random state: 25, Solver: sag, Score: 0.75
# Random state: 25, Solver: saga, Score: 0.75
# Random state: 26, Solver: lbfgs, Score: 0.75
# Random state: 26, Solver: liblinear, Score: 0.75
# Random state: 26, Solver: newton-cg, Score: 0.75
# Random state: 26, Solver: sag, Score: 0.75
# Random state: 26, Solver: saga, Score: 0.75
# Random state: 27, Solver: lbfgs, Score: 0.75
# Random state: 27, Solver: liblinear, Score: 0.75
# Random state: 27, Solver: newton-cg, Score: 0.75
# Random state: 27, Solver: sag, Score: 0.75
# Random state: 27, Solver: saga, Score: 0.75
# Random state: 28, Solver: lbfgs, Score: 0.75
# Random state: 28, Solver: liblinear, Score: 0.75
# Random state: 28, Solver: newton-cg, Score: 0.75
# Random state: 28, Solver: sag, Score: 0.75
# Random state: 28, Solver: saga, Score: 0.75
# Random state: 29, Solver: lbfgs, Score: 0.75
# Random state: 29, Solver: liblinear, Score: 0.75
# Random state: 29, Solver: newton-cg, Score: 0.75
# Random state: 29, Solver: sag, Score: 0.75
# Random state: 29, Solver: saga, Score: 0.75
# Random state: 30, Solver: lbfgs, Score: 0.75
# Random state: 30, Solver: liblinear, Score: 0.75
# Random state: 30, Solver: newton-cg, Score: 0.75
# Random state: 30, Solver: sag, Score: 0.75
# Random state: 30, Solver: saga, Score: 0.75
# Random state: 31, Solver: lbfgs, Score: 0.75
# Random state: 31, Solver: liblinear, Score: 0.75
# Random state: 31, Solver: newton-cg, Score: 0.75
# Random state: 31, Solver: sag, Score: 0.75
# Random state: 31, Solver: saga, Score: 0.75
# Random state: 32, Solver: lbfgs, Score: 0.75
# Random state: 32, Solver: liblinear, Score: 0.75
# Random state: 32, Solver: newton-cg, Score: 0.75
# Random state: 32, Solver: sag, Score: 0.75
# Random state: 32, Solver: saga, Score: 0.75
# Random state: 33, Solver: lbfgs, Score: 0.75
# Random state: 33, Solver: liblinear, Score: 0.75
# Random state: 33, Solver: newton-cg, Score: 0.75
# Random state: 33, Solver: sag, Score: 0.75
# Random state: 33, Solver: saga, Score: 0.75
# Random state: 34, Solver: lbfgs, Score: 0.75
# Random state: 34, Solver: liblinear, Score: 0.75
# Random state: 34, Solver: newton-cg, Score: 0.75
# Random state: 34, Solver: sag, Score: 0.75
# Random state: 34, Solver: saga, Score: 0.75
# Random state: 35, Solver: lbfgs, Score: 0.75
# Random state: 35, Solver: liblinear, Score: 0.75
# Random state: 35, Solver: newton-cg, Score: 0.75
# Random state: 35, Solver: sag, Score: 0.75
# Random state: 35, Solver: saga, Score: 0.75
# Random state: 36, Solver: lbfgs, Score: 0.75
# Random state: 36, Solver: liblinear, Score: 0.75
# Random state: 36, Solver: newton-cg, Score: 0.75
# Random state: 36, Solver: sag, Score: 0.75
# Random state: 36, Solver: saga, Score: 0.75
# Random state: 37, Solver: lbfgs, Score: 0.75
# Random state: 37, Solver: liblinear, Score: 0.75
# Random state: 37, Solver: newton-cg, Score: 0.75
# Random state: 37, Solver: sag, Score: 0.75
# Random state: 37, Solver: saga, Score: 0.75
# Random state: 38, Solver: lbfgs, Score: 0.75
# Random state: 38, Solver: liblinear, Score: 0.75
# Random state: 38, Solver: newton-cg, Score: 0.75
# Random state: 38, Solver: sag, Score: 0.75
# Random state: 38, Solver: saga, Score: 0.75
# Random state: 39, Solver: lbfgs, Score: 0.75
# Random state: 39, Solver: liblinear, Score: 0.75
# Random state: 39, Solver: newton-cg, Score: 0.75
# Random state: 39, Solver: sag, Score: 0.75
# Random state: 39, Solver: saga, Score: 0.75
# Random state: 40, Solver: lbfgs, Score: 0.75
# Random state: 40, Solver: liblinear, Score: 0.75
# Random state: 40, Solver: newton-cg, Score: 0.75
# Random state: 40, Solver: sag, Score: 0.75
# Random state: 40, Solver: saga, Score: 0.75
# Random state: 41, Solver: lbfgs, Score: 0.75
# Random state: 41, Solver: liblinear, Score: 0.75
# Random state: 41, Solver: newton-cg, Score: 0.75
# Random state: 41, Solver: sag, Score: 0.75
# Random state: 41, Solver: saga, Score: 0.75
# Random state: 42, Solver: lbfgs, Score: 0.75
# Random state: 42, Solver: liblinear, Score: 0.75
# Random state: 42, Solver: newton-cg, Score: 0.75
# Random state: 42, Solver: sag, Score: 0.75
# Random state: 42, Solver: saga, Score: 0.75
# Random state: 43, Solver: lbfgs, Score: 0.75
# Random state: 43, Solver: liblinear, Score: 0.75
# Random state: 43, Solver: newton-cg, Score: 0.75
# Random state: 43, Solver: sag, Score: 0.75
# Random state: 43, Solver: saga, Score: 0.75
# Random state: 44, Solver: lbfgs, Score: 0.75
# Random state: 44, Solver: liblinear, Score: 0.75
# Random state: 44, Solver: newton-cg, Score: 0.75
# Random state: 44, Solver: sag, Score: 0.75
# Random state: 44, Solver: saga, Score: 0.75
# Random state: 45, Solver: lbfgs, Score: 0.75
# Random state: 45, Solver: liblinear, Score: 0.75
# Random state: 45, Solver: newton-cg, Score: 0.75
# Random state: 45, Solver: sag, Score: 0.75
# Random state: 45, Solver: saga, Score: 0.75
# Random state: 46, Solver: lbfgs, Score: 0.75
# Random state: 46, Solver: liblinear, Score: 0.75
# Random state: 46, Solver: newton-cg, Score: 0.75
# Random state: 46, Solver: sag, Score: 0.75
# Random state: 46, Solver: saga, Score: 0.75
# Random state: 47, Solver: lbfgs, Score: 0.75
# Random state: 47, Solver: liblinear, Score: 0.75
# Random state: 47, Solver: newton-cg, Score: 0.75
# Random state: 47, Solver: sag, Score: 0.75
# Random state: 47, Solver: saga, Score: 0.75
# Random state: 48, Solver: lbfgs, Score: 0.75
# Random state: 48, Solver: liblinear, Score: 0.75
# Random state: 48, Solver: newton-cg, Score: 0.75
# Random state: 48, Solver: sag, Score: 0.75
# Random state: 48, Solver: saga, Score: 0.75
# Random state: 49, Solver: lbfgs, Score: 0.75
# Random state: 49, Solver: liblinear, Score: 0.75
# Random state: 49, Solver: newton-cg, Score: 0.75
# Random state: 49, Solver: sag, Score: 0.75
# Random state: 49, Solver: saga, Score: 0.75
# Random state: 50, Solver: lbfgs, Score: 0.75
# Random state: 50, Solver: liblinear, Score: 0.75
# Random state: 50, Solver: newton-cg, Score: 0.75
# Random state: 50, Solver: sag, Score: 0.75
# Random state: 50, Solver: saga, Score: 0.75
# Random state: 51, Solver: lbfgs, Score: 0.75
# Random state: 51, Solver: liblinear, Score: 0.75
# Random state: 51, Solver: newton-cg, Score: 0.75
# Random state: 51, Solver: sag, Score: 0.75
# Random state: 51, Solver: saga, Score: 0.75
# Random state: 52, Solver: lbfgs, Score: 0.75
# Random state: 52, Solver: liblinear, Score: 0.75
# Random state: 52, Solver: newton-cg, Score: 0.75
# Random state: 52, Solver: sag, Score: 0.75
# Random state: 52, Solver: saga, Score: 0.75
# Random state: 53, Solver: lbfgs, Score: 0.75
# Random state: 53, Solver: liblinear, Score: 0.75
# Random state: 53, Solver: newton-cg, Score: 0.75
# Random state: 53, Solver: sag, Score: 0.75
# Random state: 53, Solver: saga, Score: 0.75
# Random state: 54, Solver: lbfgs, Score: 0.75
# Random state: 54, Solver: liblinear, Score: 0.75
# Random state: 54, Solver: newton-cg, Score: 0.75
# Random state: 54, Solver: sag, Score: 0.75
# Random state: 54, Solver: saga, Score: 0.75
# Random state: 55, Solver: lbfgs, Score: 0.75
# Random state: 55, Solver: liblinear, Score: 0.75
# Random state: 55, Solver: newton-cg, Score: 0.75
# Random state: 55, Solver: sag, Score: 0.75
# Random state: 55, Solver: saga, Score: 0.75
# Random state: 56, Solver: lbfgs, Score: 0.75
# Random state: 56, Solver: liblinear, Score: 0.75
# Random state: 56, Solver: newton-cg, Score: 0.75
# Random state: 56, Solver: sag, Score: 0.75
# Random state: 56, Solver: saga, Score: 0.75
# Random state: 57, Solver: lbfgs, Score: 0.75
# Random state: 57, Solver: liblinear, Score: 0.75
# Random state: 57, Solver: newton-cg, Score: 0.75
# Random state: 57, Solver: sag, Score: 0.75
# Random state: 57, Solver: saga, Score: 0.75
# Random state: 58, Solver: lbfgs, Score: 0.75
# Random state: 58, Solver: liblinear, Score: 0.75
# Random state: 58, Solver: newton-cg, Score: 0.75
# Random state: 58, Solver: sag, Score: 0.75
# Random state: 58, Solver: saga, Score: 0.75
# Random state: 59, Solver: lbfgs, Score: 0.75
# Random state: 59, Solver: liblinear, Score: 0.75
# Random state: 59, Solver: newton-cg, Score: 0.75
# Random state: 59, Solver: sag, Score: 0.75
# Random state: 59, Solver: saga, Score: 0.75
# Random state: 60, Solver: lbfgs, Score: 0.75
# Random state: 60, Solver: liblinear, Score: 0.75
# Random state: 60, Solver: newton-cg, Score: 0.75
# Random state: 60, Solver: sag, Score: 0.75
# Random state: 60, Solver: saga, Score: 0.75
# Random state: 61, Solver: lbfgs, Score: 0.75
# Random state: 61, Solver: liblinear, Score: 0.75
# Random state: 61, Solver: newton-cg, Score: 0.75
# Random state: 61, Solver: sag, Score: 0.75
# Random state: 61, Solver: saga, Score: 0.75
# Random state: 62, Solver: lbfgs, Score: 0.75
# Random state: 62, Solver: liblinear, Score: 0.75
# Random state: 62, Solver: newton-cg, Score: 0.75
# Random state: 62, Solver: sag, Score: 0.75
# Random state: 62, Solver: saga, Score: 0.75
# Random state: 63, Solver: lbfgs, Score: 0.75
# Random state: 63, Solver: liblinear, Score: 0.75
# Random state: 63, Solver: newton-cg, Score: 0.75
# Random state: 63, Solver: sag, Score: 0.75
# Random state: 63, Solver: saga, Score: 0.75
# Random state: 64, Solver: lbfgs, Score: 0.75
# Random state: 64, Solver: liblinear, Score: 0.75
# Random state: 64, Solver: newton-cg, Score: 0.75
# Random state: 64, Solver: sag, Score: 0.75
# Random state: 64, Solver: saga, Score: 0.75
# Random state: 65, Solver: lbfgs, Score: 0.75
# Random state: 65, Solver: liblinear, Score: 0.75
# Random state: 65, Solver: newton-cg, Score: 0.75
# Random state: 65, Solver: sag, Score: 0.75
# Random state: 65, Solver: saga, Score: 0.75
# Random state: 66, Solver: lbfgs, Score: 0.75
# Random state: 66, Solver: liblinear, Score: 0.75
# Random state: 66, Solver: newton-cg, Score: 0.75
# Random state: 66, Solver: sag, Score: 0.75
# Random state: 66, Solver: saga, Score: 0.75
# Random state: 67, Solver: lbfgs, Score: 0.75
# Random state: 67, Solver: liblinear, Score: 0.75
# Random state: 67, Solver: newton-cg, Score: 0.75
# Random state: 67, Solver: sag, Score: 0.75
# Random state: 67, Solver: saga, Score: 0.75
# Random state: 68, Solver: lbfgs, Score: 0.75
# Random state: 68, Solver: liblinear, Score: 0.75
# Random state: 68, Solver: newton-cg, Score: 0.75
# Random state: 68, Solver: sag, Score: 0.75
# Random state: 68, Solver: saga, Score: 0.75
# Random state: 69, Solver: lbfgs, Score: 0.75
# Random state: 69, Solver: liblinear, Score: 0.75
# Random state: 69, Solver: newton-cg, Score: 0.75
# Random state: 69, Solver: sag, Score: 0.75
# Random state: 69, Solver: saga, Score: 0.75
# Random state: 70, Solver: lbfgs, Score: 0.75
# Random state: 70, Solver: liblinear, Score: 0.75
# Random state: 70, Solver: newton-cg, Score: 0.75
# Random state: 70, Solver: sag, Score: 0.75
# Random state: 70, Solver: saga, Score: 0.75
# Random state: 71, Solver: lbfgs, Score: 0.75
# Random state: 71, Solver: liblinear, Score: 0.75
# Random state: 71, Solver: newton-cg, Score: 0.75
# Random state: 71, Solver: sag, Score: 0.75
# Random state: 71, Solver: saga, Score: 0.75
# Random state: 72, Solver: lbfgs, Score: 0.75
# Random state: 72, Solver: liblinear, Score: 0.75
# Random state: 72, Solver: newton-cg, Score: 0.75
# Random state: 72, Solver: sag, Score: 0.75
# Random state: 72, Solver: saga, Score: 0.75
# Random state: 73, Solver: lbfgs, Score: 0.75
# Random state: 73, Solver: liblinear, Score: 0.75
# Random state: 73, Solver: newton-cg, Score: 0.75
# Random state: 73, Solver: sag, Score: 0.75
# Random state: 73, Solver: saga, Score: 0.75
# Random state: 74, Solver: lbfgs, Score: 0.75
# Random state: 74, Solver: liblinear, Score: 0.75
# Random state: 74, Solver: newton-cg, Score: 0.75
# Random state: 74, Solver: sag, Score: 0.75
# Random state: 74, Solver: saga, Score: 0.75
# Random state: 75, Solver: lbfgs, Score: 0.75
# Random state: 75, Solver: liblinear, Score: 0.75
# Random state: 75, Solver: newton-cg, Score: 0.75
# Random state: 75, Solver: sag, Score: 0.75
# Random state: 75, Solver: saga, Score: 0.75
# Random state: 76, Solver: lbfgs, Score: 0.75
# Random state: 76, Solver: liblinear, Score: 0.75
# Random state: 76, Solver: newton-cg, Score: 0.75
# Random state: 76, Solver: sag, Score: 0.75
# Random state: 76, Solver: saga, Score: 0.75
# Random state: 77, Solver: lbfgs, Score: 0.75
# Random state: 77, Solver: liblinear, Score: 0.75
# Random state: 77, Solver: newton-cg, Score: 0.75
# Random state: 77, Solver: sag, Score: 0.75
# Random state: 77, Solver: saga, Score: 0.75
# Random state: 78, Solver: lbfgs, Score: 0.75
# Random state: 78, Solver: liblinear, Score: 0.75
# Random state: 78, Solver: newton-cg, Score: 0.75
# Random state: 78, Solver: sag, Score: 0.75
# Random state: 78, Solver: saga, Score: 0.75
# Random state: 79, Solver: lbfgs, Score: 0.75
# Random state: 79, Solver: liblinear, Score: 0.75
# Random state: 79, Solver: newton-cg, Score: 0.75
# Random state: 79, Solver: sag, Score: 0.75
# Random state: 79, Solver: saga, Score: 0.75
# Random state: 80, Solver: lbfgs, Score: 0.75
# Random state: 80, Solver: liblinear, Score: 0.75
# Random state: 80, Solver: newton-cg, Score: 0.75
# Random state: 80, Solver: sag, Score: 0.75
# Random state: 80, Solver: saga, Score: 0.75
# Random state: 81, Solver: lbfgs, Score: 0.75
# Random state: 81, Solver: liblinear, Score: 0.75
# Random state: 81, Solver: newton-cg, Score: 0.75
# Random state: 81, Solver: sag, Score: 0.75
# Random state: 81, Solver: saga, Score: 0.75
# Random state: 82, Solver: lbfgs, Score: 0.75
# Random state: 82, Solver: liblinear, Score: 0.75
# Random state: 82, Solver: newton-cg, Score: 0.75
# Random state: 82, Solver: sag, Score: 0.75
# Random state: 82, Solver: saga, Score: 0.75
# Random state: 83, Solver: lbfgs, Score: 0.75
# Random state: 83, Solver: liblinear, Score: 0.75
# Random state: 83, Solver: newton-cg, Score: 0.75
# Random state: 83, Solver: sag, Score: 0.75
# Random state: 83, Solver: saga, Score: 0.75
# Random state: 84, Solver: lbfgs, Score: 0.75
# Random state: 84, Solver: liblinear, Score: 0.75
# Random state: 84, Solver: newton-cg, Score: 0.75
# Random state: 84, Solver: sag, Score: 0.75
# Random state: 84, Solver: saga, Score: 0.75
# Random state: 85, Solver: lbfgs, Score: 0.75
# Random state: 85, Solver: liblinear, Score: 0.75
# Random state: 85, Solver: newton-cg, Score: 0.75
# Random state: 85, Solver: sag, Score: 0.75
# Random state: 85, Solver: saga, Score: 0.75
# Random state: 86, Solver: lbfgs, Score: 0.75
# Random state: 86, Solver: liblinear, Score: 0.75
# Random state: 86, Solver: newton-cg, Score: 0.75
# Random state: 86, Solver: sag, Score: 0.75
# Random state: 86, Solver: saga, Score: 0.75
# Random state: 87, Solver: lbfgs, Score: 0.75
# Random state: 87, Solver: liblinear, Score: 0.75
# Random state: 87, Solver: newton-cg, Score: 0.75
# Random state: 87, Solver: sag, Score: 0.75
# Random state: 87, Solver: saga, Score: 0.75
# Random state: 88, Solver: lbfgs, Score: 0.75
# Random state: 88, Solver: liblinear, Score: 0.75
# Random state: 88, Solver: newton-cg, Score: 0.75
# Random state: 88, Solver: sag, Score: 0.75
# Random state: 88, Solver: saga, Score: 0.75
# Random state: 89, Solver: lbfgs, Score: 0.75
# Random state: 89, Solver: liblinear, Score: 0.75
# Random state: 89, Solver: newton-cg, Score: 0.75
# Random state: 89, Solver: sag, Score: 0.75
# Random state: 89, Solver: saga, Score: 0.75
# Random state: 90, Solver: lbfgs, Score: 0.75
# Random state: 90, Solver: liblinear, Score: 0.75
# Random state: 90, Solver: newton-cg, Score: 0.75
# Random state: 90, Solver: sag, Score: 0.75
# Random state: 90, Solver: saga, Score: 0.75
# Random state: 91, Solver: lbfgs, Score: 0.75
# Random state: 91, Solver: liblinear, Score: 0.75
# Random state: 91, Solver: newton-cg, Score: 0.75
# Random state: 91, Solver: sag, Score: 0.75
# Random state: 91, Solver: saga, Score: 0.75
# Random state: 92, Solver: lbfgs, Score: 0.75
# Random state: 92, Solver: liblinear, Score: 0.75
# Random state: 92, Solver: newton-cg, Score: 0.75
# Random state: 92, Solver: sag, Score: 0.75
# Random state: 92, Solver: saga, Score: 0.75
# Random state: 93, Solver: lbfgs, Score: 0.75
# Random state: 93, Solver: liblinear, Score: 0.75
# Random state: 93, Solver: newton-cg, Score: 0.75
# Random state: 93, Solver: sag, Score: 0.75
# Random state: 93, Solver: saga, Score: 0.75
# Random state: 94, Solver: lbfgs, Score: 0.75
# Random state: 94, Solver: liblinear, Score: 0.75
# Random state: 94, Solver: newton-cg, Score: 0.75
# Random state: 94, Solver: sag, Score: 0.75
# Random state: 94, Solver: saga, Score: 0.75
# Random state: 95, Solver: lbfgs, Score: 0.75
# Random state: 95, Solver: liblinear, Score: 0.75
# Random state: 95, Solver: newton-cg, Score: 0.75
# Random state: 95, Solver: sag, Score: 0.75
# Random state: 95, Solver: saga, Score: 0.75
# Random state: 96, Solver: lbfgs, Score: 0.75
# Random state: 96, Solver: liblinear, Score: 0.75
# Random state: 96, Solver: newton-cg, Score: 0.75
# Random state: 96, Solver: sag, Score: 0.75
# Random state: 96, Solver: saga, Score: 0.75
# Random state: 97, Solver: lbfgs, Score: 0.75
# Random state: 97, Solver: liblinear, Score: 0.75
# Random state: 97, Solver: newton-cg, Score: 0.75
# Random state: 97, Solver: sag, Score: 0.75
# Random state: 97, Solver: saga, Score: 0.75
# Random state: 98, Solver: lbfgs, Score: 0.75
# Random state: 98, Solver: liblinear, Score: 0.75
# Random state: 98, Solver: newton-cg, Score: 0.75
# Random state: 98, Solver: sag, Score: 0.75
# Random state: 98, Solver: saga, Score: 0.75
# Random state: 99, Solver: lbfgs, Score: 0.75
# Random state: 99, Solver: liblinear, Score: 0.75
# Random state: 99, Solver: newton-cg, Score: 0.75
# Random state: 99, Solver: sag, Score: 0.75
# Random state: 99, Solver: saga, Score: 0.75
# Random state: 100, Solver: lbfgs, Score: 0.75
# Random state: 100, Solver: liblinear, Score: 0.75
# Random state: 100, Solver: newton-cg, Score: 0.75
# Random state: 100, Solver: sag, Score: 0.75
# Random state: 100, Solver: saga, Score: 0.75
# Random state: 101, Solver: lbfgs, Score: 0.75
# Random state: 101, Solver: liblinear, Score: 0.75
# Random state: 101, Solver: newton-cg, Score: 0.75
# Random state: 101, Solver: sag, Score: 0.75
# Random state: 101, Solver: saga, Score: 0.75
# Random state: 102, Solver: lbfgs, Score: 0.75
# Random state: 102, Solver: liblinear, Score: 0.75
# Random state: 102, Solver: newton-cg, Score: 0.75
# Random state: 102, Solver: sag, Score: 0.75
# Random state: 102, Solver: saga, Score: 0.75
# Random state: 103, Solver: lbfgs, Score: 0.75
# Random state: 103, Solver: liblinear, Score: 0.75
# Random state: 103, Solver: newton-cg, Score: 0.75
# Random state: 103, Solver: sag, Score: 0.75
# Random state: 103, Solver: saga, Score: 0.75
# Random state: 104, Solver: lbfgs, Score: 0.75
# Random state: 104, Solver: liblinear, Score: 0.75
# Random state: 104, Solver: newton-cg, Score: 0.75
# Random state: 104, Solver: sag, Score: 0.75
# Random state: 104, Solver: saga, Score: 0.75
# Random state: 105, Solver: lbfgs, Score: 0.75
# Random state: 105, Solver: liblinear, Score: 0.75
# Random state: 105, Solver: newton-cg, Score: 0.75
# Random state: 105, Solver: sag, Score: 0.75
# Random state: 105, Solver: saga, Score: 0.75
# Random state: 106, Solver: lbfgs, Score: 0.75
# Random state: 106, Solver: liblinear, Score: 0.75
# Random state: 106, Solver: newton-cg, Score: 0.75
# Random state: 106, Solver: sag, Score: 0.75
# Random state: 106, Solver: saga, Score: 0.75
# Random state: 107, Solver: lbfgs, Score: 0.75
# Random state: 107, Solver: liblinear, Score: 0.75
# Random state: 107, Solver: newton-cg, Score: 0.75
# Random state: 107, Solver: sag, Score: 0.75
# Random state: 107, Solver: saga, Score: 0.75
# Random state: 108, Solver: lbfgs, Score: 0.75
# Random state: 108, Solver: liblinear, Score: 0.75
# Random state: 108, Solver: newton-cg, Score: 0.75
# Random state: 108, Solver: sag, Score: 0.75
# Random state: 108, Solver: saga, Score: 0.75
# Random state: 109, Solver: lbfgs, Score: 0.75
# Random state: 109, Solver: liblinear, Score: 0.75
# Random state: 109, Solver: newton-cg, Score: 0.75
# Random state: 109, Solver: sag, Score: 0.75
# Random state: 109, Solver: saga, Score: 0.75
# Random state: 110, Solver: lbfgs, Score: 0.75
# Random state: 110, Solver: liblinear, Score: 0.75
# Random state: 110, Solver: newton-cg, Score: 0.75
# Random state: 110, Solver: sag, Score: 0.75
# Random state: 110, Solver: saga, Score: 0.75
# Random state: 111, Solver: lbfgs, Score: 0.75
# Random state: 111, Solver: liblinear, Score: 0.75
# Random state: 111, Solver: newton-cg, Score: 0.75
# Random state: 111, Solver: sag, Score: 0.75
# Random state: 111, Solver: saga, Score: 0.75
# Random state: 112, Solver: lbfgs, Score: 0.75
# Random state: 112, Solver: liblinear, Score: 0.75
# Random state: 112, Solver: newton-cg, Score: 0.75
# Random state: 112, Solver: sag, Score: 0.75
# Random state: 112, Solver: saga, Score: 0.75
# Random state: 113, Solver: lbfgs, Score: 0.75
# Random state: 113, Solver: liblinear, Score: 0.75
# Random state: 113, Solver: newton-cg, Score: 0.75
# Random state: 113, Solver: sag, Score: 0.75
# Random state: 113, Solver: saga, Score: 0.75
# Random state: 114, Solver: lbfgs, Score: 0.75
# Random state: 114, Solver: liblinear, Score: 0.75
# Random state: 114, Solver: newton-cg, Score: 0.75
# Random state: 114, Solver: sag, Score: 0.75
# Random state: 114, Solver: saga, Score: 0.75
# Random state: 115, Solver: lbfgs, Score: 0.75
# Random state: 115, Solver: liblinear, Score: 0.75
# Random state: 115, Solver: newton-cg, Score: 0.75
# Random state: 115, Solver: sag, Score: 0.75
# Random state: 115, Solver: saga, Score: 0.75
# Random state: 116, Solver: lbfgs, Score: 0.75
# Random state: 116, Solver: liblinear, Score: 0.75
# Random state: 116, Solver: newton-cg, Score: 0.75
# Random state: 116, Solver: sag, Score: 0.75
# Random state: 116, Solver: saga, Score: 0.75
# Random state: 117, Solver: lbfgs, Score: 0.75
# Random state: 117, Solver: liblinear, Score: 0.75
# Random state: 117, Solver: newton-cg, Score: 0.75
# Random state: 117, Solver: sag, Score: 0.75
# Random state: 117, Solver: saga, Score: 0.75
# Random state: 118, Solver: lbfgs, Score: 0.75
# Random state: 118, Solver: liblinear, Score: 0.75
# Random state: 118, Solver: newton-cg, Score: 0.75
# Random state: 118, Solver: sag, Score: 0.75
# Random state: 118, Solver: saga, Score: 0.75
# Random state: 119, Solver: lbfgs, Score: 0.75
# Random state: 119, Solver: liblinear, Score: 0.75
# Random state: 119, Solver: newton-cg, Score: 0.75
# Random state: 119, Solver: sag, Score: 0.75
# Random state: 119, Solver: saga, Score: 0.75
# Random state: 120, Solver: lbfgs, Score: 0.75
# Random state: 120, Solver: liblinear, Score: 0.75
# Random state: 120, Solver: newton-cg, Score: 0.75
# Random state: 120, Solver: sag, Score: 0.75
# Random state: 120, Solver: saga, Score: 0.75
# Random state: 121, Solver: lbfgs, Score: 0.75
# Random state: 121, Solver: liblinear, Score: 0.75
# Random state: 121, Solver: newton-cg, Score: 0.75
# Random state: 121, Solver: sag, Score: 0.75
# Random state: 121, Solver: saga, Score: 0.75
# Random state: 122, Solver: lbfgs, Score: 0.75
# Random state: 122, Solver: liblinear, Score: 0.75
# Random state: 122, Solver: newton-cg, Score: 0.75
# Random state: 122, Solver: sag, Score: 0.75
# Random state: 122, Solver: saga, Score: 0.75
# Random state: 123, Solver: lbfgs, Score: 0.75
# Random state: 123, Solver: liblinear, Score: 0.75
# Random state: 123, Solver: newton-cg, Score: 0.75
# Random state: 123, Solver: sag, Score: 0.75
# Random state: 123, Solver: saga, Score: 0.75
# Random state: 124, Solver: lbfgs, Score: 0.75
# Random state: 124, Solver: liblinear, Score: 0.75
# Random state: 124, Solver: newton-cg, Score: 0.75
# Random state: 124, Solver: sag, Score: 0.75
# Random state: 124, Solver: saga, Score: 0.75
# Random state: 125, Solver: lbfgs, Score: 0.75
# Random state: 125, Solver: liblinear, Score: 0.75
# Random state: 125, Solver: newton-cg, Score: 0.75
# Random state: 125, Solver: sag, Score: 0.75
# Random state: 125, Solver: saga, Score: 0.75
# Random state: 126, Solver: lbfgs, Score: 0.75
# Random state: 126, Solver: liblinear, Score: 0.75
# Random state: 126, Solver: newton-cg, Score: 0.75
# Random state: 126, Solver: sag, Score: 0.75
# Random state: 126, Solver: saga, Score: 0.75
# Random state: 127, Solver: lbfgs, Score: 0.75
# Random state: 127, Solver: liblinear, Score: 0.75
# Random state: 127, Solver: newton-cg, Score: 0.75
# Random state: 127, Solver: sag, Score: 0.75
# Random state: 127, Solver: saga, Score: 0.75
# Random state: 128, Solver: lbfgs, Score: 0.75
# Random state: 128, Solver: liblinear, Score: 0.75
# Random state: 128, Solver: newton-cg, Score: 0.75
# Random state: 128, Solver: sag, Score: 0.75
# Random state: 128, Solver: saga, Score: 0.75
# Random state: 129, Solver: lbfgs, Score: 0.75
# Random state: 129, Solver: liblinear, Score: 0.75
# Random state: 129, Solver: newton-cg, Score: 0.75
# Random state: 129, Solver: sag, Score: 0.75
# Random state: 129, Solver: saga, Score: 0.75
# Random state: 130, Solver: lbfgs, Score: 0.75
# Random state: 130, Solver: liblinear, Score: 0.75
# Random state: 130, Solver: newton-cg, Score: 0.75
# Random state: 130, Solver: sag, Score: 0.75
# Random state: 130, Solver: saga, Score: 0.75
# Random state: 131, Solver: lbfgs, Score: 0.75
# Random state: 131, Solver: liblinear, Score: 0.75
# Random state: 131, Solver: newton-cg, Score: 0.75
# Random state: 131, Solver: sag, Score: 0.75
# Random state: 131, Solver: saga, Score: 0.75
# Random state: 132, Solver: lbfgs, Score: 0.75
# Random state: 132, Solver: liblinear, Score: 0.75
# Random state: 132, Solver: newton-cg, Score: 0.75
# Random state: 132, Solver: sag, Score: 0.75
# Random state: 132, Solver: saga, Score: 0.75
# Random state: 133, Solver: lbfgs, Score: 0.75
# Random state: 133, Solver: liblinear, Score: 0.75
# Random state: 133, Solver: newton-cg, Score: 0.75
# Random state: 133, Solver: sag, Score: 0.75
# Random state: 133, Solver: saga, Score: 0.75
# Random state: 134, Solver: lbfgs, Score: 0.75
# Random state: 134, Solver: liblinear, Score: 0.75
# Random state: 134, Solver: newton-cg, Score: 0.75
# Random state: 134, Solver: sag, Score: 0.75
# Random state: 134, Solver: saga, Score: 0.75
# Random state: 135, Solver: lbfgs, Score: 0.75
# Random state: 135, Solver: liblinear, Score: 0.75
# Random state: 135, Solver: newton-cg, Score: 0.75
# Random state: 135, Solver: sag, Score: 0.75
# Random state: 135, Solver: saga, Score: 0.75
# Random state: 136, Solver: lbfgs, Score: 0.75
# Random state: 136, Solver: liblinear, Score: 0.75
# Random state: 136, Solver: newton-cg, Score: 0.75
# Random state: 136, Solver: sag, Score: 0.75
# Random state: 136, Solver: saga, Score: 0.75
# Random state: 137, Solver: lbfgs, Score: 0.75
# Random state: 137, Solver: liblinear, Score: 0.75
# Random state: 137, Solver: newton-cg, Score: 0.75
# Random state: 137, Solver: sag, Score: 0.75
# Random state: 137, Solver: saga, Score: 0.75
# Random state: 138, Solver: lbfgs, Score: 0.75
# Random state: 138, Solver: liblinear, Score: 0.75
# Random state: 138, Solver: newton-cg, Score: 0.75
# Random state: 138, Solver: sag, Score: 0.75
# Random state: 138, Solver: saga, Score: 0.75
# Random state: 139, Solver: lbfgs, Score: 0.75
# Random state: 139, Solver: liblinear, Score: 0.75
# Random state: 139, Solver: newton-cg, Score: 0.75
# Random state: 139, Solver: sag, Score: 0.75
# Random state: 139, Solver: saga, Score: 0.75
# Random state: 140, Solver: lbfgs, Score: 0.75
# Random state: 140, Solver: liblinear, Score: 0.75
# Random state: 140, Solver: newton-cg, Score: 0.75
# Random state: 140, Solver: sag, Score: 0.75
# Random state: 140, Solver: saga, Score: 0.75
# Random state: 141, Solver: lbfgs, Score: 0.75
# Random state: 141, Solver: liblinear, Score: 0.75
# Random state: 141, Solver: newton-cg, Score: 0.75
# Random state: 141, Solver: sag, Score: 0.75
# Random state: 141, Solver: saga, Score: 0.75
# Random state: 142, Solver: lbfgs, Score: 0.75
# Random state: 142, Solver: liblinear, Score: 0.75
# Random state: 142, Solver: newton-cg, Score: 0.75
# Random state: 142, Solver: sag, Score: 0.75
# Random state: 142, Solver: saga, Score: 0.75
# Random state: 143, Solver: lbfgs, Score: 0.75
# Random state: 143, Solver: liblinear, Score: 0.75
# Random state: 143, Solver: newton-cg, Score: 0.75
# Random state: 143, Solver: sag, Score: 0.75
# Random state: 143, Solver: saga, Score: 0.75
# Random state: 144, Solver: lbfgs, Score: 0.75
# Random state: 144, Solver: liblinear, Score: 0.75
# Random state: 144, Solver: newton-cg, Score: 0.75
# Random state: 144, Solver: sag, Score: 0.75
# Random state: 144, Solver: saga, Score: 0.75
# Random state: 145, Solver: lbfgs, Score: 0.75
# Random state: 145, Solver: liblinear, Score: 0.75
# Random state: 145, Solver: newton-cg, Score: 0.75
# Random state: 145, Solver: sag, Score: 0.75
# Random state: 145, Solver: saga, Score: 0.75
# Random state: 146, Solver: lbfgs, Score: 0.75
# Random state: 146, Solver: liblinear, Score: 0.75
# Random state: 146, Solver: newton-cg, Score: 0.75
# Random state: 146, Solver: sag, Score: 0.75
# Random state: 146, Solver: saga, Score: 0.75
# Random state: 147, Solver: lbfgs, Score: 0.75
# Random state: 147, Solver: liblinear, Score: 0.75
# Random state: 147, Solver: newton-cg, Score: 0.75
# Random state: 147, Solver: sag, Score: 0.75
# Random state: 147, Solver: saga, Score: 0.75
# Random state: 148, Solver: lbfgs, Score: 0.75
# Random state: 148, Solver: liblinear, Score: 0.75
# Random state: 148, Solver: newton-cg, Score: 0.75
# Random state: 148, Solver: sag, Score: 0.75
# Random state: 148, Solver: saga, Score: 0.75
# Random state: 149, Solver: lbfgs, Score: 0.75
# Random state: 149, Solver: liblinear, Score: 0.75
# Random state: 149, Solver: newton-cg, Score: 0.75
# Random state: 149, Solver: sag, Score: 0.75
# Random state: 149, Solver: saga, Score: 0.75
# Random state: 150, Solver: lbfgs, Score: 0.75
# Random state: 150, Solver: liblinear, Score: 0.75
# Random state: 150, Solver: newton-cg, Score: 0.75
# Random state: 150, Solver: sag, Score: 0.75
# Random state: 150, Solver: saga, Score: 0.75
# Random state: 151, Solver: lbfgs, Score: 0.75
# Random state: 151, Solver: liblinear, Score: 0.75
# Random state: 151, Solver: newton-cg, Score: 0.75
# Random state: 151, Solver: sag, Score: 0.75
# Random state: 151, Solver: saga, Score: 0.75
# Random state: 152, Solver: lbfgs, Score: 0.75
# Random state: 152, Solver: liblinear, Score: 0.75
# Random state: 152, Solver: newton-cg, Score: 0.75
# Random state: 152, Solver: sag, Score: 0.75
# Random state: 152, Solver: saga, Score: 0.75
# Random state: 153, Solver: lbfgs, Score: 0.75
# Random state: 153, Solver: liblinear, Score: 0.75
# Random state: 153, Solver: newton-cg, Score: 0.75
# Random state: 153, Solver: sag, Score: 0.75
# Random state: 153, Solver: saga, Score: 0.75
# Random state: 154, Solver: lbfgs, Score: 0.75
# Random state: 154, Solver: liblinear, Score: 0.75
# Random state: 154, Solver: newton-cg, Score: 0.75
# Random state: 154, Solver: sag, Score: 0.75
# Random state: 154, Solver: saga, Score: 0.75
# Random state: 155, Solver: lbfgs, Score: 0.75
# Random state: 155, Solver: liblinear, Score: 0.75
# Random state: 155, Solver: newton-cg, Score: 0.75
# Random state: 155, Solver: sag, Score: 0.75
# Random state: 155, Solver: saga, Score: 0.75
# Random state: 156, Solver: lbfgs, Score: 0.75
# Random state: 156, Solver: liblinear, Score: 0.75
# Random state: 156, Solver: newton-cg, Score: 0.75
# Random state: 156, Solver: sag, Score: 0.75
# Random state: 156, Solver: saga, Score: 0.75
# Random state: 157, Solver: lbfgs, Score: 0.75
# Random state: 157, Solver: liblinear, Score: 0.75
# Random state: 157, Solver: newton-cg, Score: 0.75
# Random state: 157, Solver: sag, Score: 0.75
# Random state: 157, Solver: saga, Score: 0.75
# Random state: 158, Solver: lbfgs, Score: 0.75
# Random state: 158, Solver: liblinear, Score: 0.75
# Random state: 158, Solver: newton-cg, Score: 0.75
# Random state: 158, Solver: sag, Score: 0.75
# Random state: 158, Solver: saga, Score: 0.75
# Random state: 159, Solver: lbfgs, Score: 0.75
# Random state: 159, Solver: liblinear, Score: 0.75
# Random state: 159, Solver: newton-cg, Score: 0.75
# Random state: 159, Solver: sag, Score: 0.75
# Random state: 159, Solver: saga, Score: 0.75
# Random state: 160, Solver: lbfgs, Score: 0.75
# Random state: 160, Solver: liblinear, Score: 0.75
# Random state: 160, Solver: newton-cg, Score: 0.75
# Random state: 160, Solver: sag, Score: 0.75
# Random state: 160, Solver: saga, Score: 0.75
# Random state: 161, Solver: lbfgs, Score: 0.75
# Random state: 161, Solver: liblinear, Score: 0.75
# Random state: 161, Solver: newton-cg, Score: 0.75
# Random state: 161, Solver: sag, Score: 0.75
# Random state: 161, Solver: saga, Score: 0.75
# Random state: 162, Solver: lbfgs, Score: 0.75
# Random state: 162, Solver: liblinear, Score: 0.75
# Random state: 162, Solver: newton-cg, Score: 0.75
# Random state: 162, Solver: sag, Score: 0.75
# Random state: 162, Solver: saga, Score: 0.75
# Random state: 163, Solver: lbfgs, Score: 0.75
# Random state: 163, Solver: liblinear, Score: 0.75
# Random state: 163, Solver: newton-cg, Score: 0.75
# Random state: 163, Solver: sag, Score: 0.75
# Random state: 163, Solver: saga, Score: 0.75
# Random state: 164, Solver: lbfgs, Score: 0.75
# Random state: 164, Solver: liblinear, Score: 0.75
# Random state: 164, Solver: newton-cg, Score: 0.75
# Random state: 164, Solver: sag, Score: 0.75
# Random state: 164, Solver: saga, Score: 0.75
# Random state: 165, Solver: lbfgs, Score: 0.75
# Random state: 165, Solver: liblinear, Score: 0.75
# Random state: 165, Solver: newton-cg, Score: 0.75
# Random state: 165, Solver: sag, Score: 0.75
# Random state: 165, Solver: saga, Score: 0.75
# Random state: 166, Solver: lbfgs, Score: 0.75
# Random state: 166, Solver: liblinear, Score: 0.75
# Random state: 166, Solver: newton-cg, Score: 0.75
# Random state: 166, Solver: sag, Score: 0.75
# Random state: 166, Solver: saga, Score: 0.75
# Random state: 167, Solver: lbfgs, Score: 0.75
# Random state: 167, Solver: liblinear, Score: 0.75
# Random state: 167, Solver: newton-cg, Score: 0.75
# Random state: 167, Solver: sag, Score: 0.75
# Random state: 167, Solver: saga, Score: 0.75
# Random state: 168, Solver: lbfgs, Score: 0.75
# Random state: 168, Solver: liblinear, Score: 0.75
# Random state: 168, Solver: newton-cg, Score: 0.75
# Random state: 168, Solver: sag, Score: 0.75
# Random state: 168, Solver: saga, Score: 0.75
# Random state: 169, Solver: lbfgs, Score: 0.75
# Random state: 169, Solver: liblinear, Score: 0.75
# Random state: 169, Solver: newton-cg, Score: 0.75
# Random state: 169, Solver: sag, Score: 0.75
# Random state: 169, Solver: saga, Score: 0.75
# Random state: 170, Solver: lbfgs, Score: 0.75
# Random state: 170, Solver: liblinear, Score: 0.75
# Random state: 170, Solver: newton-cg, Score: 0.75
# Random state: 170, Solver: sag, Score: 0.75
# Random state: 170, Solver: saga, Score: 0.75
# Random state: 171, Solver: lbfgs, Score: 0.75
# Random state: 171, Solver: liblinear, Score: 0.75
# Random state: 171, Solver: newton-cg, Score: 0.75
# Random state: 171, Solver: sag, Score: 0.75
# Random state: 171, Solver: saga, Score: 0.75
# Random state: 172, Solver: lbfgs, Score: 0.75
# Random state: 172, Solver: liblinear, Score: 0.75
# Random state: 172, Solver: newton-cg, Score: 0.75
# Random state: 172, Solver: sag, Score: 0.75
# Random state: 172, Solver: saga, Score: 0.75
# Random state: 173, Solver: lbfgs, Score: 0.75
# Random state: 173, Solver: liblinear, Score: 0.75
# Random state: 173, Solver: newton-cg, Score: 0.75
# Random state: 173, Solver: sag, Score: 0.75
# Random state: 173, Solver: saga, Score: 0.75
# Random state: 174, Solver: lbfgs, Score: 0.75
# Random state: 174, Solver: liblinear, Score: 0.75
# Random state: 174, Solver: newton-cg, Score: 0.75
# Random state: 174, Solver: sag, Score: 0.75
# Random state: 174, Solver: saga, Score: 0.75
# Random state: 175, Solver: lbfgs, Score: 0.75
# Random state: 175, Solver: liblinear, Score: 0.75
# Random state: 175, Solver: newton-cg, Score: 0.75
# Random state: 175, Solver: sag, Score: 0.75
# Random state: 175, Solver: saga, Score: 0.75
# Random state: 176, Solver: lbfgs, Score: 0.75
# Random state: 176, Solver: liblinear, Score: 0.75
# Random state: 176, Solver: newton-cg, Score: 0.75
# Random state: 176, Solver: sag, Score: 0.75
# Random state: 176, Solver: saga, Score: 0.75
# Random state: 177, Solver: lbfgs, Score: 0.75
# Random state: 177, Solver: liblinear, Score: 0.75
# Random state: 177, Solver: newton-cg, Score: 0.75
# Random state: 177, Solver: sag, Score: 0.75
# Random state: 177, Solver: saga, Score: 0.75
# Random state: 178, Solver: lbfgs, Score: 0.75
# Random state: 178, Solver: liblinear, Score: 0.75
# Random state: 178, Solver: newton-cg, Score: 0.75
# Random state: 178, Solver: sag, Score: 0.75
# Random state: 178, Solver: saga, Score: 0.75
# Random state: 179, Solver: lbfgs, Score: 0.75
# Random state: 179, Solver: liblinear, Score: 0.75
# Random state: 179, Solver: newton-cg, Score: 0.75
# Random state: 179, Solver: sag, Score: 0.75
# Random state: 179, Solver: saga, Score: 0.75
# Random state: 180, Solver: lbfgs, Score: 0.75
# Random state: 180, Solver: liblinear, Score: 0.75
# Random state: 180, Solver: newton-cg, Score: 0.75
# Random state: 180, Solver: sag, Score: 0.75
# Random state: 180, Solver: saga, Score: 0.75
# Random state: 181, Solver: lbfgs, Score: 0.75
# Random state: 181, Solver: liblinear, Score: 0.75
# Random state: 181, Solver: newton-cg, Score: 0.75
# Random state: 181, Solver: sag, Score: 0.75
# Random state: 181, Solver: saga, Score: 0.75
# Random state: 182, Solver: lbfgs, Score: 0.75
# Random state: 182, Solver: liblinear, Score: 0.75
# Random state: 182, Solver: newton-cg, Score: 0.75
# Random state: 182, Solver: sag, Score: 0.75
# Random state: 182, Solver: saga, Score: 0.75
# Random state: 183, Solver: lbfgs, Score: 0.75
# Random state: 183, Solver: liblinear, Score: 0.75
# Random state: 183, Solver: newton-cg, Score: 0.75
# Random state: 183, Solver: sag, Score: 0.75
# Random state: 183, Solver: saga, Score: 0.75
# Random state: 184, Solver: lbfgs, Score: 0.75
# Random state: 184, Solver: liblinear, Score: 0.75
# Random state: 184, Solver: newton-cg, Score: 0.75
# Random state: 184, Solver: sag, Score: 0.75
# Random state: 184, Solver: saga, Score: 0.75
# Random state: 185, Solver: lbfgs, Score: 0.75
# Random state: 185, Solver: liblinear, Score: 0.75
# Random state: 185, Solver: newton-cg, Score: 0.75
# Random state: 185, Solver: sag, Score: 0.75
# Random state: 185, Solver: saga, Score: 0.75
# Random state: 186, Solver: lbfgs, Score: 0.75
# Random state: 186, Solver: liblinear, Score: 0.75
# Random state: 186, Solver: newton-cg, Score: 0.75
# Random state: 186, Solver: sag, Score: 0.75
# Random state: 186, Solver: saga, Score: 0.75
# Random state: 187, Solver: lbfgs, Score: 0.75
# Random state: 187, Solver: liblinear, Score: 0.75
# Random state: 187, Solver: newton-cg, Score: 0.75
# Random state: 187, Solver: sag, Score: 0.75
# Random state: 187, Solver: saga, Score: 0.75
# Random state: 188, Solver: lbfgs, Score: 0.75
# Random state: 188, Solver: liblinear, Score: 0.75
# Random state: 188, Solver: newton-cg, Score: 0.75
# Random state: 188, Solver: sag, Score: 0.75
# Random state: 188, Solver: saga, Score: 0.75
# Random state: 189, Solver: lbfgs, Score: 0.75
# Random state: 189, Solver: liblinear, Score: 0.75
# Random state: 189, Solver: newton-cg, Score: 0.75
# Random state: 189, Solver: sag, Score: 0.75
# Random state: 189, Solver: saga, Score: 0.75
# Random state: 190, Solver: lbfgs, Score: 0.75
# Random state: 190, Solver: liblinear, Score: 0.75
# Random state: 190, Solver: newton-cg, Score: 0.75
# Random state: 190, Solver: sag, Score: 0.75
# Random state: 190, Solver: saga, Score: 0.75
# Random state: 191, Solver: lbfgs, Score: 0.75
# Random state: 191, Solver: liblinear, Score: 0.75
# Random state: 191, Solver: newton-cg, Score: 0.75
# Random state: 191, Solver: sag, Score: 0.75
# Random state: 191, Solver: saga, Score: 0.75
# Random state: 192, Solver: lbfgs, Score: 0.75
# Random state: 192, Solver: liblinear, Score: 0.75
# Random state: 192, Solver: newton-cg, Score: 0.75
# Random state: 192, Solver: sag, Score: 0.75
# Random state: 192, Solver: saga, Score: 0.75
# Random state: 193, Solver: lbfgs, Score: 0.75
# Random state: 193, Solver: liblinear, Score: 0.75
# Random state: 193, Solver: newton-cg, Score: 0.75
# Random state: 193, Solver: sag, Score: 0.75
# Random state: 193, Solver: saga, Score: 0.75
# Random state: 194, Solver: lbfgs, Score: 0.75
# Random state: 194, Solver: liblinear, Score: 0.75
# Random state: 194, Solver: newton-cg, Score: 0.75
# Random state: 194, Solver: sag, Score: 0.75
# Random state: 194, Solver: saga, Score: 0.75
# Random state: 195, Solver: lbfgs, Score: 0.75
# Random state: 195, Solver: liblinear, Score: 0.75
# Random state: 195, Solver: newton-cg, Score: 0.75
# Random state: 195, Solver: sag, Score: 0.75
# Random state: 195, Solver: saga, Score: 0.75
# Random state: 196, Solver: lbfgs, Score: 0.75
# Random state: 196, Solver: liblinear, Score: 0.75
# Random state: 196, Solver: newton-cg, Score: 0.75
# Random state: 196, Solver: sag, Score: 0.75
# Random state: 196, Solver: saga, Score: 0.75
# Random state: 197, Solver: lbfgs, Score: 0.75
# Random state: 197, Solver: liblinear, Score: 0.75
# Random state: 197, Solver: newton-cg, Score: 0.75
# Random state: 197, Solver: sag, Score: 0.75
# Random state: 197, Solver: saga, Score: 0.75
# Random state: 198, Solver: lbfgs, Score: 0.75
# Random state: 198, Solver: liblinear, Score: 0.75
# Random state: 198, Solver: newton-cg, Score: 0.75
# Random state: 198, Solver: sag, Score: 0.75
# Random state: 198, Solver: saga, Score: 0.75
# Random state: 199, Solver: lbfgs, Score: 0.75
# Random state: 199, Solver: liblinear, Score: 0.75
# Random state: 199, Solver: newton-cg, Score: 0.75
# Random state: 199, Solver: sag, Score: 0.75
# Random state: 199, Solver: saga, Score: 0.75
# Random state: 200, Solver: lbfgs, Score: 0.75
# Random state: 200, Solver: liblinear, Score: 0.75
# Random state: 200, Solver: newton-cg, Score: 0.75
# Random state: 200, Solver: sag, Score: 0.75
# Random state: 200, Solver: saga, Score: 0.75
# Random state: 201, Solver: lbfgs, Score: 0.75
# Random state: 201, Solver: liblinear, Score: 0.75
# Random state: 201, Solver: newton-cg, Score: 0.75
# Random state: 201, Solver: sag, Score: 0.75
# Random state: 201, Solver: saga, Score: 0.75
# Random state: 202, Solver: lbfgs, Score: 0.75
# Random state: 202, Solver: liblinear, Score: 0.75
# Random state: 202, Solver: newton-cg, Score: 0.75
# Random state: 202, Solver: sag, Score: 0.75
# Random state: 202, Solver: saga, Score: 0.75
# Random state: 203, Solver: lbfgs, Score: 0.75
# Random state: 203, Solver: liblinear, Score: 0.75
# Random state: 203, Solver: newton-cg, Score: 0.75
# Random state: 203, Solver: sag, Score: 0.75
# Random state: 203, Solver: saga, Score: 0.75
# Random state: 204, Solver: lbfgs, Score: 0.75
# Random state: 204, Solver: liblinear, Score: 0.75
# Random state: 204, Solver: newton-cg, Score: 0.75
# Random state: 204, Solver: sag, Score: 0.75
# Random state: 204, Solver: saga, Score: 0.75
# Random state: 205, Solver: lbfgs, Score: 0.75
# Random state: 205, Solver: liblinear, Score: 0.75
# Random state: 205, Solver: newton-cg, Score: 0.75
# Random state: 205, Solver: sag, Score: 0.75
# Random state: 205, Solver: saga, Score: 0.75
# Random state: 206, Solver: lbfgs, Score: 0.75
# Random state: 206, Solver: liblinear, Score: 0.75
# ...
# Random state: 432, Solver: saga, Score: 0.75
# Random state: 433, Solver: lbfgs, Score: 0.75
# Random state: 433, Solver: liblinear, Score: 0.75
# Random state: 433, Solver: newton-cg, Score: 0.75
# Random state: 433, Solver: sag, Score: 0.75
# Random state: 433, Solver: saga, Score: 0.75
# Random state: 434, Solver: lbfgs, Score: 0.75
# Random state: 434, Solver: liblinear, Score: 0.75
# Random state: 434, Solver: newton-cg, Score: 0.75
# Random state: 434, Solver: sag, Score: 0.75
# Random state: 434, Solver: saga, Score: 0.75
# Random state: 435, Solver: lbfgs, Score: 0.75
# Random state: 435, Solver: liblinear, Score: 0.75
# Random state: 435, Solver: newton-cg, Score: 0.75
# Random state: 435, Solver: sag, Score: 0.75
# Random state: 435, Solver: saga, Score: 0.75
# Random state: 436, Solver: lbfgs, Score: 0.75
# Random state: 436, Solver: liblinear, Score: 0.75
# Random state: 436, Solver: newton-cg, Score: 0.75
# Random state: 436, Solver: sag, Score: 0.75
# Random state: 436, Solver: saga, Score: 0.75
# Random state: 437, Solver: lbfgs, Score: 0.75
# Random state: 437, Solver: liblinear, Score: 0.75
# Random state: 437, Solver: newton-cg, Score: 0.75
# Random state: 437, Solver: sag, Score: 0.75
# Random state: 437, Solver: saga, Score: 0.75
# Random state: 438, Solver: lbfgs, Score: 0.75
# Random state: 438, Solver: liblinear, Score: 0.75
# Random state: 438, Solver: newton-cg, Score: 0.75
# Random state: 438, Solver: sag, Score: 0.75
# Random state: 438, Solver: saga, Score: 0.75
# Random state: 439, Solver: lbfgs, Score: 0.75
# Random state: 439, Solver: liblinear, Score: 0.75
# Random state: 439, Solver: newton-cg, Score: 0.75
# Random state: 439, Solver: sag, Score: 0.75
# Random state: 439, Solver: saga, Score: 0.75
# Random state: 440, Solver: lbfgs, Score: 0.75
# Random state: 440, Solver: liblinear, Score: 0.75
# Random state: 440, Solver: newton-cg, Score: 0.75
# Random state: 440, Solver: sag, Score: 0.75
# Random state: 440, Solver: saga, Score: 0.75
# Random state: 441, Solver: lbfgs, Score: 0.75
# Random state: 441, Solver: liblinear, Score: 0.75
# Random state: 441, Solver: newton-cg, Score: 0.75
# Random state: 441, Solver: sag, Score: 0.75
# Random state: 441, Solver: saga, Score: 0.75
# Random state: 442, Solver: lbfgs, Score: 0.75
# Random state: 442, Solver: liblinear, Score: 0.75
# Random state: 442, Solver: newton-cg, Score: 0.75
# Random state: 442, Solver: sag, Score: 0.75
# Random state: 442, Solver: saga, Score: 0.75
# Random state: 443, Solver: lbfgs, Score: 0.75
# Random state: 443, Solver: liblinear, Score: 0.75
# Random state: 443, Solver: newton-cg, Score: 0.75
# Random state: 443, Solver: sag, Score: 0.75
# Random state: 443, Solver: saga, Score: 0.75
# Random state: 444, Solver: lbfgs, Score: 0.75
# Random state: 444, Solver: liblinear, Score: 0.75
# Random state: 444, Solver: newton-cg, Score: 0.75
# Random state: 444, Solver: sag, Score: 0.75
# Random state: 444, Solver: saga, Score: 0.75
# Random state: 445, Solver: lbfgs, Score: 0.75
# Random state: 445, Solver: liblinear, Score: 0.75
# Random state: 445, Solver: newton-cg, Score: 0.75
# Random state: 445, Solver: sag, Score: 0.75
# Random state: 445, Solver: saga, Score: 0.75
# Random state: 446, Solver: lbfgs, Score: 0.75
# Random state: 446, Solver: liblinear, Score: 0.75
# Random state: 446, Solver: newton-cg, Score: 0.75
# Random state: 446, Solver: sag, Score: 0.75
# Random state: 446, Solver: saga, Score: 0.75
# Random state: 447, Solver: lbfgs, Score: 0.75
# Random state: 447, Solver: liblinear, Score: 0.75
# Random state: 447, Solver: newton-cg, Score: 0.75
# Random state: 447, Solver: sag, Score: 0.75
# Random state: 447, Solver: saga, Score: 0.75
# Random state: 448, Solver: lbfgs, Score: 0.75
# Random state: 448, Solver: liblinear, Score: 0.75
# Random state: 448, Solver: newton-cg, Score: 0.75
# Random state: 448, Solver: sag, Score: 0.75
# Random state: 448, Solver: saga, Score: 0.75
# Random state: 449, Solver: lbfgs, Score: 0.75
# Random state: 449, Solver: liblinear, Score: 0.75
# Random state: 449, Solver: newton-cg, Score: 0.75
# Random state: 449, Solver: sag, Score: 0.75
# Random state: 449, Solver: saga, Score: 0.75
# Random state: 450, Solver: lbfgs, Score: 0.75
# Random state: 450, Solver: liblinear, Score: 0.75
# Random state: 450, Solver: newton-cg, Score: 0.75
# Random state: 450, Solver: sag, Score: 0.75
# Random state: 450, Solver: saga, Score: 0.75
# Random state: 451, Solver: lbfgs, Score: 0.75
# Random state: 451, Solver: liblinear, Score: 0.75
# Random state: 451, Solver: newton-cg, Score: 0.75
# Random state: 451, Solver: sag, Score: 0.75
# Random state: 451, Solver: saga, Score: 0.75
# Random state: 452, Solver: lbfgs, Score: 0.75
# Random state: 452, Solver: liblinear, Score: 0.75
# Random state: 452, Solver: newton-cg, Score: 0.75
# Random state: 452, Solver: sag, Score: 0.75
# Random state: 452, Solver: saga, Score: 0.75
# Random state: 453, Solver: lbfgs, Score: 0.75
# Random state: 453, Solver: liblinear, Score: 0.75
# Random state: 453, Solver: newton-cg, Score: 0.75
# Random state: 453, Solver: sag, Score: 0.75
# Random state: 453, Solver: saga, Score: 0.75
# Random state: 454, Solver: lbfgs, Score: 0.75
# Random state: 454, Solver: liblinear, Score: 0.75
# Random state: 454, Solver: newton-cg, Score: 0.75
# Random state: 454, Solver: sag, Score: 0.75
# Random state: 454, Solver: saga, Score: 0.75
# Random state: 455, Solver: lbfgs, Score: 0.75
# Random state: 455, Solver: liblinear, Score: 0.75
# Random state: 455, Solver: newton-cg, Score: 0.75
# Random state: 455, Solver: sag, Score: 0.75
# Random state: 455, Solver: saga, Score: 0.75
# Random state: 456, Solver: lbfgs, Score: 0.75
# Random state: 456, Solver: liblinear, Score: 0.75
# Random state: 456, Solver: newton-cg, Score: 0.75
# Random state: 456, Solver: sag, Score: 0.75
# Random state: 456, Solver: saga, Score: 0.75
# Random state: 457, Solver: lbfgs, Score: 0.75
# Random state: 457, Solver: liblinear, Score: 0.75
# Random state: 457, Solver: newton-cg, Score: 0.75
# Random state: 457, Solver: sag, Score: 0.75
# Random state: 457, Solver: saga, Score: 0.75
# Random state: 458, Solver: lbfgs, Score: 0.75
# Random state: 458, Solver: liblinear, Score: 0.75
# Random state: 458, Solver: newton-cg, Score: 0.75
# Random state: 458, Solver: sag, Score: 0.75
# Random state: 458, Solver: saga, Score: 0.75
# Random state: 459, Solver: lbfgs, Score: 0.75
# Random state: 459, Solver: liblinear, Score: 0.75
# Random state: 459, Solver: newton-cg, Score: 0.75
# Random state: 459, Solver: sag, Score: 0.75
# Random state: 459, Solver: saga, Score: 0.75
# Random state: 460, Solver: lbfgs, Score: 0.75
# Random state: 460, Solver: liblinear, Score: 0.75
# Random state: 460, Solver: newton-cg, Score: 0.75
# Random state: 460, Solver: sag, Score: 0.75
# Random state: 460, Solver: saga, Score: 0.75
# Random state: 461, Solver: lbfgs, Score: 0.75
# Random state: 461, Solver: liblinear, Score: 0.75
# Random state: 461, Solver: newton-cg, Score: 0.75
# Random state: 461, Solver: sag, Score: 0.75
# Random state: 461, Solver: saga, Score: 0.75
# Random state: 462, Solver: lbfgs, Score: 0.75
# Random state: 462, Solver: liblinear, Score: 0.75
# Random state: 462, Solver: newton-cg, Score: 0.75
# Random state: 462, Solver: sag, Score: 0.75
# Random state: 462, Solver: saga, Score: 0.75
# Random state: 463, Solver: lbfgs, Score: 0.75
# Random state: 463, Solver: liblinear, Score: 0.75
# Random state: 463, Solver: newton-cg, Score: 0.75
# Random state: 463, Solver: sag, Score: 0.75
# Random state: 463, Solver: saga, Score: 0.75
# Random state: 464, Solver: lbfgs, Score: 0.75
# Random state: 464, Solver: liblinear, Score: 0.75
# Random state: 464, Solver: newton-cg, Score: 0.75
# Random state: 464, Solver: sag, Score: 0.75
# Random state: 464, Solver: saga, Score: 0.75
# Random state: 465, Solver: lbfgs, Score: 0.75
# Random state: 465, Solver: liblinear, Score: 0.75
# Random state: 465, Solver: newton-cg, Score: 0.75
# Random state: 465, Solver: sag, Score: 0.75
# Random state: 465, Solver: saga, Score: 0.75
# Random state: 466, Solver: lbfgs, Score: 0.75
# Random state: 466, Solver: liblinear, Score: 0.75
# Random state: 466, Solver: newton-cg, Score: 0.75
# Random state: 466, Solver: sag, Score: 0.75
# Random state: 466, Solver: saga, Score: 0.75
# Random state: 467, Solver: lbfgs, Score: 0.75
# Random state: 467, Solver: liblinear, Score: 0.75
# Random state: 467, Solver: newton-cg, Score: 0.75
# Random state: 467, Solver: sag, Score: 0.75
# Random state: 467, Solver: saga, Score: 0.75
# Random state: 468, Solver: lbfgs, Score: 0.75
# Random state: 468, Solver: liblinear, Score: 0.75
# Random state: 468, Solver: newton-cg, Score: 0.75
# Random state: 468, Solver: sag, Score: 0.75
# Random state: 468, Solver: saga, Score: 0.75
# Random state: 469, Solver: lbfgs, Score: 0.75
# Random state: 469, Solver: liblinear, Score: 0.75
# Random state: 469, Solver: newton-cg, Score: 0.75
# Random state: 469, Solver: sag, Score: 0.75
# Random state: 469, Solver: saga, Score: 0.75
# Random state: 470, Solver: lbfgs, Score: 0.75
# Random state: 470, Solver: liblinear, Score: 0.75
# Random state: 470, Solver: newton-cg, Score: 0.75
# Random state: 470, Solver: sag, Score: 0.75
# Random state: 470, Solver: saga, Score: 0.75
# Random state: 471, Solver: lbfgs, Score: 0.75
# Random state: 471, Solver: liblinear, Score: 0.75
# Random state: 471, Solver: newton-cg, Score: 0.75
# Random state: 471, Solver: sag, Score: 0.75
# Random state: 471, Solver: saga, Score: 0.75
# Random state: 472, Solver: lbfgs, Score: 0.75
# Random state: 472, Solver: liblinear, Score: 0.75
# Random state: 472, Solver: newton-cg, Score: 0.75
# Random state: 472, Solver: sag, Score: 0.75
# Random state: 472, Solver: saga, Score: 0.75
# Random state: 473, Solver: lbfgs, Score: 0.75
# Random state: 473, Solver: liblinear, Score: 0.75
# Random state: 473, Solver: newton-cg, Score: 0.75
# Random state: 473, Solver: sag, Score: 0.75
# Random state: 473, Solver: saga, Score: 0.75
# Random state: 474, Solver: lbfgs, Score: 0.75
# Random state: 474, Solver: liblinear, Score: 0.75
# Random state: 474, Solver: newton-cg, Score: 0.75
# Random state: 474, Solver: sag, Score: 0.75
# Random state: 474, Solver: saga, Score: 0.75
# Random state: 475, Solver: lbfgs, Score: 0.75
# Random state: 475, Solver: liblinear, Score: 0.75
# Random state: 475, Solver: newton-cg, Score: 0.75
# Random state: 475, Solver: sag, Score: 0.75
# Random state: 475, Solver: saga, Score: 0.75
# Random state: 476, Solver: lbfgs, Score: 0.75
# Random state: 476, Solver: liblinear, Score: 0.75
# Random state: 476, Solver: newton-cg, Score: 0.75
# Random state: 476, Solver: sag, Score: 0.75
# Random state: 476, Solver: saga, Score: 0.75
# Random state: 477, Solver: lbfgs, Score: 0.75
# Random state: 477, Solver: liblinear, Score: 0.75
# Random state: 477, Solver: newton-cg, Score: 0.75
# Random state: 477, Solver: sag, Score: 0.75
# Random state: 477, Solver: saga, Score: 0.75
# Random state: 478, Solver: lbfgs, Score: 0.75
# Random state: 478, Solver: liblinear, Score: 0.75
# Random state: 478, Solver: newton-cg, Score: 0.75
# Random state: 478, Solver: sag, Score: 0.75
# Random state: 478, Solver: saga, Score: 0.75
# Random state: 479, Solver: lbfgs, Score: 0.75
# Random state: 479, Solver: liblinear, Score: 0.75
# Random state: 479, Solver: newton-cg, Score: 0.75
# Random state: 479, Solver: sag, Score: 0.75
# Random state: 479, Solver: saga, Score: 0.75
# Random state: 480, Solver: lbfgs, Score: 0.75
# Random state: 480, Solver: liblinear, Score: 0.75
# Random state: 480, Solver: newton-cg, Score: 0.75
# Random state: 480, Solver: sag, Score: 0.75
# Random state: 480, Solver: saga, Score: 0.75
# Random state: 481, Solver: lbfgs, Score: 0.75
# Random state: 481, Solver: liblinear, Score: 0.75
# Random state: 481, Solver: newton-cg, Score: 0.75
# Random state: 481, Solver: sag, Score: 0.75
# Random state: 481, Solver: saga, Score: 0.75
# Random state: 482, Solver: lbfgs, Score: 0.75
# Random state: 482, Solver: liblinear, Score: 0.75
# Random state: 482, Solver: newton-cg, Score: 0.75
# Random state: 482, Solver: sag, Score: 0.75
# Random state: 482, Solver: saga, Score: 0.75
# Random state: 483, Solver: lbfgs, Score: 0.75
# Random state: 483, Solver: liblinear, Score: 0.75
# Random state: 483, Solver: newton-cg, Score: 0.75
# Random state: 483, Solver: sag, Score: 0.75
# Random state: 483, Solver: saga, Score: 0.75
# Random state: 484, Solver: lbfgs, Score: 0.75
# Random state: 484, Solver: liblinear, Score: 0.75
# Random state: 484, Solver: newton-cg, Score: 0.75
# Random state: 484, Solver: sag, Score: 0.75
# Random state: 484, Solver: saga, Score: 0.75
# Random state: 485, Solver: lbfgs, Score: 0.75
# Random state: 485, Solver: liblinear, Score: 0.75
# Random state: 485, Solver: newton-cg, Score: 0.75
# Random state: 485, Solver: sag, Score: 0.75
# Random state: 485, Solver: saga, Score: 0.75
# Random state: 486, Solver: lbfgs, Score: 0.75
# Random state: 486, Solver: liblinear, Score: 0.75
# Random state: 486, Solver: newton-cg, Score: 0.75
# Random state: 486, Solver: sag, Score: 0.75
# Random state: 486, Solver: saga, Score: 0.75
# Random state: 487, Solver: lbfgs, Score: 0.75
# Random state: 487, Solver: liblinear, Score: 0.75
# Random state: 487, Solver: newton-cg, Score: 0.75
# Random state: 487, Solver: sag, Score: 0.75
# Random state: 487, Solver: saga, Score: 0.75
# Random state: 488, Solver: lbfgs, Score: 0.75
# Random state: 488, Solver: liblinear, Score: 0.75
# Random state: 488, Solver: newton-cg, Score: 0.75
# Random state: 488, Solver: sag, Score: 0.75
# Random state: 488, Solver: saga, Score: 0.75
# Random state: 489, Solver: lbfgs, Score: 0.75
# Random state: 489, Solver: liblinear, Score: 0.75
# Random state: 489, Solver: newton-cg, Score: 0.75
# Random state: 489, Solver: sag, Score: 0.75
# Random state: 489, Solver: saga, Score: 0.75
# Random state: 490, Solver: lbfgs, Score: 0.75
# Random state: 490, Solver: liblinear, Score: 0.75
# Random state: 490, Solver: newton-cg, Score: 0.75
# Random state: 490, Solver: sag, Score: 0.75
# Random state: 490, Solver: saga, Score: 0.75
# Random state: 491, Solver: lbfgs, Score: 0.75
# Random state: 491, Solver: liblinear, Score: 0.75
# Random state: 491, Solver: newton-cg, Score: 0.75
# Random state: 491, Solver: sag, Score: 0.75
# Random state: 491, Solver: saga, Score: 0.75
# Random state: 492, Solver: lbfgs, Score: 0.75
# Random state: 492, Solver: liblinear, Score: 0.75
# Random state: 492, Solver: newton-cg, Score: 0.75
# Random state: 492, Solver: sag, Score: 0.75
# Random state: 492, Solver: saga, Score: 0.75
# Random state: 493, Solver: lbfgs, Score: 0.75
# Random state: 493, Solver: liblinear, Score: 0.75
# Random state: 493, Solver: newton-cg, Score: 0.75
# Random state: 493, Solver: sag, Score: 0.75
# Random state: 493, Solver: saga, Score: 0.75
# Random state: 494, Solver: lbfgs, Score: 0.75
# Random state: 494, Solver: liblinear, Score: 0.75
# Random state: 494, Solver: newton-cg, Score: 0.75
# Random state: 494, Solver: sag, Score: 0.75
# Random state: 494, Solver: saga, Score: 0.75
# Random state: 495, Solver: lbfgs, Score: 0.75
# Random state: 495, Solver: liblinear, Score: 0.75
# Random state: 495, Solver: newton-cg, Score: 0.75
# Random state: 495, Solver: sag, Score: 0.75
# Random state: 495, Solver: saga, Score: 0.75
# Random state: 496, Solver: lbfgs, Score: 0.75
# Random state: 496, Solver: liblinear, Score: 0.75
# Random state: 496, Solver: newton-cg, Score: 0.75
# Random state: 496, Solver: sag, Score: 0.75
# Random state: 496, Solver: saga, Score: 0.75
# Random state: 497, Solver: lbfgs, Score: 0.75
# Random state: 497, Solver: liblinear, Score: 0.75
# Random state: 497, Solver: newton-cg, Score: 0.75
# Random state: 497, Solver: sag, Score: 0.75
# Random state: 497, Solver: saga, Score: 0.75
# Random state: 498, Solver: lbfgs, Score: 0.75
# Random state: 498, Solver: liblinear, Score: 0.75
# Random state: 498, Solver: newton-cg, Score: 0.75
# Random state: 498, Solver: sag, Score: 0.75
# Random state: 498, Solver: saga, Score: 0.75
# Random state: 499, Solver: lbfgs, Score: 0.75
# Random state: 499, Solver: liblinear, Score: 0.75
# Random state: 499, Solver: newton-cg, Score: 0.75
# Random state: 499, Solver: sag, Score: 0.75
# Random state: 499, Solver: saga, Score: 0.75
# Coefficients: [[ 0.04269351  0.04268344 -0.43031824]]
# Intercept: [0.06467714]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# i) Using the code below that generates 3 concentric circles, fit a logisitc regression model to it and plot the decision boundary.

# %%
t, _ = datasets.make_blobs(n_samples=1500, centers=centers, cluster_std=2,
                                random_state=0)

# CIRCLES
def generate_circles_data(t):
    def label(x):
        if x[0]**2 + x[1]**2 >= 2 and x[0]**2 + x[1]**2 < 8:
            return 1
        if x[0]**2 + x[1]**2 >= 8:
            return 2
        return 0
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0]**2 + x[1]**2 < 1.8 or x[0]**2 + x[1]**2 > 2.2) and (x[0]**2 + x[1]**2 < 7.8 or x[0]**2 + x[1]**2 > 8.2), t)))
    Y = np.array([label(x) for x in X])
    return X, Y

X, Y = generate_circles_data(t)

poly = PolynomialFeatures(2)
lr = LogisticRegression(verbose=2)
model = make_pipeline(poly, lr).fit(X, Y)

h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]
Z = model.predict(meshData)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.title("Decision Boundary for Concentric Circles")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
...
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/aryanagarwal/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# Ellipsis
